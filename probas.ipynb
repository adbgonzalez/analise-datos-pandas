# %%
import pandas as pd

# %%
df = pd.read_csv("data/penguins.csv")
df.head()
df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
df.hist(bins=20)
# Out:
# array([[<Axes: title={'center': 'bill_length_mm'}>,
#         <Axes: title={'center': 'bill_depth_mm'}>],
#        [<Axes: title={'center': 'flipper_length_mm'}>,
#         <Axes: title={'center': 'body_mass_g'}>]], dtype=object)

# %%
df.groupby("species")["body_mass_g"].mean().plot(kind="bar")
plt.ylabel("Peso medio (g)")
plt.title("Peso corporal medio por especie")
# Out:
# Text(0.5, 1.0, 'Peso corporal medio por especie')

# %%
pd.crosstab(df["species"], df["sex"]).plot(kind="bar", stacked=True)
plt.title("Número de machos e femias por especie")
# Out:
# Text(0.5, 1.0, 'Número de machos e femias por especie')

# %%
import seaborn as sns
sns.boxplot(x="species", y="flipper_length_mm", data=df)
plt.title("Distribución da lonxitude das aletas por especie")
# Out:
# Text(0.5, 1.0, 'Distribución da lonxitude das aletas por especie')

# %%
plt.scatter(df["flipper_length_mm"], df["body_mass_g"])
plt.xlabel("Lonxitude da aleta (mm)")
plt.ylabel("Peso corporal (g)")
plt.title("Relación lonxitude da aleta vs peso")
sns.scatterplot(x="flipper_length_mm", y="body_mass_g", hue="species", data=df)
# Out:
# <Axes: title={'center': 'Relación lonxitude da aleta vs peso'}, xlabel='Lonxitude da aleta (mm)', ylabel='Peso corporal (g)'>

# %%
pd.crosstab(df["species"], df["sex"]).plot(kind="bar", stacked=True)
plt.title("Número de machos e femias por especie")
# Out:
# Text(0.5, 1.0, 'Número de machos e femias por especie')

# %%
df.plot.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.plot.scatter()
#
# TypeError: PlotAccessor.scatter() missing 2 required positional arguments: 'x' and 'y'
